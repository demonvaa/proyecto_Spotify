# %% [markdown]
# # Top Spotify songs from 2010-2019 - BY YEAR

# %%
import pandas as pd
df= pd.read_csv("top50contry.csv",encoding='latin-1')
print(df.info())
df
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   title       1000 non-null   str
#  2   artist      1000 non-null   str
#  3   top genre   985 non-null    str
#  4   year        1000 non-null   int64
#  5   added       1000 non-null   str
#  6   bpm         999 non-null    float64
#  7   nrgy        999 non-null    float64
#  8   dnce        999 non-null    float64
#  9   dB          999 non-null    float64
#  10  live        999 non-null    float64
#  11  val         999 non-null    float64
#  12  dur         1000 non-null   int64
#  13  acous       999 non-null    float64
#  14  spch        999 non-null    float64
#  15  pop         1000 non-null   int64
#  16  country     1000 non-null   str
# dtypes: float64(8), int64(4), str(5)
# memory usage: 132.9 KB
# None
# ...

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'title', 'artist', 'top genre', 'year', 'added', 'bpm',
#        'nrgy', 'dnce', 'dB', 'live', 'val', 'dur', 'acous', 'spch', 'pop',
#        'country'],
#       dtype='str')

# %% [markdown]
# | **Columna** | **Tipo** | **Qué significa** |
# | --- | --- | --- |
# | **Unnamed: 0** | int | Índice del dataset (no aporta información, puedes borrarlo). |
# | **title** | str | Título de la canción. |
# | **artist** | str | Nombre del artista o grupo. |
# | **top genre** | str | Género principal del artista según Spotify (pop, rap, reggaeton, etc.). |
# | **year** | int | Año de lanzamiento de la canción. |
# | **added** | str | Fecha en la que la canción fue añadida a la playlist. |
# | **bpm** | float | Beats per minute: velocidad/tempo de la canción. |
# | **nrgy** | float | Energía (0–100): intensidad y actividad de la canción. |
# | **dnce** | float | Danceability (0–100): qué tan bailable es. |
# | **dB** | float | Loudness: volumen promedio en decibelios. |
# | **live** | float | Liveness (0–100): probabilidad de que sea una grabación en vivo. |
# | **val** | float | Valence (0–100): qué tan “feliz/positiva” suena la canción. |
# | **dur** | int | Duración en milisegundos. |
# | **acous** | float | Acousticness (0–100): qué tan acústica es la canción. |
# | **spch** | float | Speechiness (0–100): presencia de voz hablada (rap, spoken word). |
# | **pop** | int | Popularidad en Spotify (0–100). |
# | **country** | str | País al que pertenece el ranking donde aparece la canción. |

# %% [markdown]
# 🎧 Qué se le puede preguntar a una página tipo “Top 50 Spotify songs by each country”
# Aunque no pueda leer el contenido exacto, sí puedo ayudarte a formular preguntas inteligentes que este tipo de ranking permite.
#
# 🌍 1. Preguntas por país
# “¿Cuáles son las canciones más escuchadas en España?”
#
# “¿Qué artista lidera el ranking en México?”
#
# “¿Qué diferencias hay entre el top de Argentina y Chile?”
#
# “¿Qué países tienen más canciones en inglés en su top 50?”
#
# 📈 2. Preguntas de análisis
# “¿Qué géneros dominan en Europa?”
#
# “¿Qué artistas aparecen en más de un país?”
#
# “¿Qué canción es la más repetida globalmente?”
#
# “¿Qué países tienen más variedad de artistas?”
#
# 🔁 3. Comparaciones
# “Compara el top 50 de España con el de Portugal.”
#
# “¿Qué países comparten la misma canción número 1?”
#
# “¿Qué país tiene más artistas locales en su top?”
#
# 🧠 4. Preguntas de patrones y tendencias
# “¿Qué tendencias globales se ven en los rankings?”
#
# “¿Qué países escuchan más reggaetón?”
#
# “¿Qué países tienen más presencia de música electrónica?”
#
# “¿Qué artistas están creciendo en varios países a la vez?”
#
# 🎤 5. Preguntas sobre artistas
# “¿En qué países aparece Bad Bunny en el top 50?”
#
# “¿Qué artista aparece más veces en todos los rankings?”
#
# “¿Qué artistas son exclusivos de un solo país?”
#
# 🗺️ 6. Preguntas geográficas
# “¿Qué países tienen los tops más parecidos?”
#
# “¿Qué regiones del mundo escuchan más pop?”
#
# “¿Qué países tienen más música local en su top?”
#
# 🧩 7. Preguntas avanzadas
# “Hazme un resumen global de los artistas más presentes.”
#
# “Dime qué países tienen más canciones repetidas entre sí.”
#
# “Dime qué países tienen más artistas internacionales.”

# %%
✔ Tabla 1 — Top 50 de España
python
df_spain = df[df["country"] == "Spain"]
✔ Tabla 2 — Top 50 de México
python
df_mexico = df[df["country"] == "Mexico"]
✔ Tabla 3 — Canciones más repetidas globalmente
python
df_global = df.groupby("song").size().reset_index(name="count")
✔ Tabla 4 — Artistas más presentes
python
df_artists = df.groupby("artist").size().reset_index(name="count")
✔ Tabla 5 — Tabla solo con canciones
python
df_songs = df[["song"]]
✔ Tabla 6 — Tabla solo con países
python
df_countries = df[["country"]].drop_duplicates()

# %%
✔ Tabla 1 — Top 50 de España
python
df_spain = df[df["country"] == "Spain"]
✔ Tabla 2 — Top 50 de México
python
df_mexico = df[df["country"] == "Mexico"]
✔ Tabla 3 — Canciones más repetidas globalmente
python
df_global = df.groupby("song").size().reset_index(name="count")
✔ Tabla 4 — Artistas más presentes
python
df_artists = df.groupby("artist").size().reset_index(name="count")
✔ Tabla 5 — Tabla solo con canciones
python
df_songs = df[["song"]]
✔ Tabla 6 — Tabla solo con países
python
df_countries = df[["country"]].drop_duplicates()
