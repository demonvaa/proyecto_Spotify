# %%
import pandas as pd
df = pd.read_csv('/Users/albertomarques/Proyectos/Bootcamp/Curso2026/Semana_3/Proyecto_semana_3/Info/top50contry.csv', encoding='latin-1')

# %%
df.shape

# %%
df.head()

# %%
df.columns

# %%
df.info()

# %%
df.describe().T

# %%
df.describe(include= 'str').T

# %%
df.nunique()

# %%
df['country'].unique()

# %%
df['country'].value_counts()

# %%
print(df['top genre'].unique())

# %%
df['artist'].unique()

# %%
df.rename(columns={'top genre':'genre'}, inplace = True)

# %%
name_artist = list(df['artist'].unique())

# %%
def assign_id(lst):
    
    return {i+1:name for i,name in enumerate(lst)}

# %%
map_cambio = assign_id(name_artist)
df['artist_id'] = df['artist'].map(map_cambio)
df
